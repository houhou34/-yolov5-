# %%
import os
from PIL import Image

def splitimage(src, rownum, colnum, dstpath):
    img = Image.open(src)
    w, h = img.size
    if rownum <= h and colnum <= w:
        print('Original image info: %sx%s, %s, %s' % (w, h, img.format, img.mode))
        print('开始处理图片切割, 请稍候...')

        s = os.path.split(src)
        if dstpath == '':
            dstpath = s[0]
        fn = s[1].split('.')
        basename = fn[0]
        ext = fn[-1]

        num = 0
        rowheight = h // rownum
        colwidth = w // colnum
        for r in range(rownum):
            for c in range(colnum):
                box = (c * colwidth, r * rowheight, (c + 1) * colwidth, (r + 1) * rowheight)
                img.crop(box).save(os.path.join(dstpath, basename + '_' + str(num) + '.' + ext), ext)
                num = num + 1

        print('图片切割完毕，共生成 %s 张小图片。' % num)
    else:
        print('不合法的行列切割参数！')

source_dir = "/Users/a123/Desktop/Archive/脚本/result1/"
filenames = glob('{}/*'.format(source_dir))
for src in filenames:
    print(src)
# src = '/Users/a123/Desktop/Archive/脚本/result1/001.jpeg'
    if os.path.isfile(src):
        dstpath = '/Users/a123/Desktop/Archive/脚本/result2'
        if (dstpath == '') or os.path.exists(dstpath):
            row = 6
            col = 6
            splitimage(src, row, col, dstpath)
        else:
            print('图片输出目录 %s 不存在！' % dstpath)
    else:
        print('图片文件 %s 不存在！' % src)
# Out:
# /Users/a123/Desktop/Archive/脚本/result1/236.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/261.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/148.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/298.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/277.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/220.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/109.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/037.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/172.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/060.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/125.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/076.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/099.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/133.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/021.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/164.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/113.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/056.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/144.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/001.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/282.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/152.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/017.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/294.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/105.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/040.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/191.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/257.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/083.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/129.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/200.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/095.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/216.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/187.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/168.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/241.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/240.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/186.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/169.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/217.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/094.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/201.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/082.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/128.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/256.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/190.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/104.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/041.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/295.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/153.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/016.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/283.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/145.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/112.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/057.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/020.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/165.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/077.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/098.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/132.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/061.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/124.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/036.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/173.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/108.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/221.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/299.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/276.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/149.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/260.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/237.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/115.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/050.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/142.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/007.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/284.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/154.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/011.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/292.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/103.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/046.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/197.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/178.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/251.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/085.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/206.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/139.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/093.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/210.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/181.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/247.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/230.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/119.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/288.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/267.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/271.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/158.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/226.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/031.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/174.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/066.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/123.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/089.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/070.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/135.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/027.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/162.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/026.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/163.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/071.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/134.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/067.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/122.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/088.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/030.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/175.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/227.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/159.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/270.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/289.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/266.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/118.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/231.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/246.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/180.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/211.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/138.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/092.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/207.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/084.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/250.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/196.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/179.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/102.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/047.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/293.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/155.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/010.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/285.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/143.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/006.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/114.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/051.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/245.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/183.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/029.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/212.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/091.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/204.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/087.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/068.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/253.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/195.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/228.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/044.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/101.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/290.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/013.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/156.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/269.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/286.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/005.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/140.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/052.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/117.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/160.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/025.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/249.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/137.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/072.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/121.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/064.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/208.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/176.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/199.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/033.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/048.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/224.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/273.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/009.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/265.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/232.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/233.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/264.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/008.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/272.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/225.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/049.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/177.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/198.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/032.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/209.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/120.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/065.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/136.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/073.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/248.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/161.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/024.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/053.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/116.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/004.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/141.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/268.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/287.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/012.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/157.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/291.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/045.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/100.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/229.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/194.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/252.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/086.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/069.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/205.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/090.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/213.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/182.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/028.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/244.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/166.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/023.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/189.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/131.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/074.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/218.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/127.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/062.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/170.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/035.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/259.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/222.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/019.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/275.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/263.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/058.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/234.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/243.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/185.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/214.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/097.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/078.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/202.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/081.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/255.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/039.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/193.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/042.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/107.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/279.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/296.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/015.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/150.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/280.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/003.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/146.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/238.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/054.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/111.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/055.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/110.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/239.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/002.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/147.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/281.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/014.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/151.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/278.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/297.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/043.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/106.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/038.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/192.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/254.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/080.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/203.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/096.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/079.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/215.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/184.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/242.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/235.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/059.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/262.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/274.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/018.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/223.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/258.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/171.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/034.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/126.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/063.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/219.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/130.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/075.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/167.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/022.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
# /Users/a123/Desktop/Archive/脚本/result1/188.jpeg
# Original image info: 3600x3600, JPEG, RGB
# 开始处理图片切割, 请稍候...
# 图片切割完毕，共生成 36 张小图片。
