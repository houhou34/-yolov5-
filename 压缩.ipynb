# %%
import os
import numpy as np
import pandas as pd
import cv2
from glob import glob

# # 压缩至 3000*3000
def func_resize(srcimg,dstw = 3600,dsth = 3600):
    h = srcimg.shape[0]
    w = srcimg.shape[1]
    if (h == dsth) and (w == dstw):
        return srcing
    dstimg = cv2.resize(srcimg,(dstw,dsth))
    return dstimg


# img = cv2.imread('/Users/a123/Desktop/Archive/train_copy/0002.jpg')
# img.shape
# img2 = func_resize(img)
# cv2.imwrite('/Users/a123/Desktop/Archive/脚本/result/0002.jpg',img2)

source_dir = "/Users/a123/Desktop/Archive/testfiles"
filenames = glob('{}/*'.format(source_dir))

j = 1
for i in filenames:
    img = cv2.imread(i)
    img2 = func_resize(img)
    print(i)
    
    path = '/Users/a123/Desktop/Archive/脚本/result1/' + format(str(j),'0>3s') + '.jpeg'
    cv2.imwrite(path,img2,[int( cv2.IMWRITE_JPEG_QUALITY), 95])
    j = j + 1
# Out:
# /Users/a123/Desktop/Archive/testfiles/0007.jpg
# /Users/a123/Desktop/Archive/testfiles/0005.jpg
# /Users/a123/Desktop/Archive/testfiles/0009.jpg
# /Users/a123/Desktop/Archive/testfiles/0021.jpg
# /Users/a123/Desktop/Archive/testfiles/0143.jpg
# /Users/a123/Desktop/Archive/testfiles/0091.jpg
# /Users/a123/Desktop/Archive/testfiles/0095.jpg
# /Users/a123/Desktop/Archive/testfiles/0069.jpg
